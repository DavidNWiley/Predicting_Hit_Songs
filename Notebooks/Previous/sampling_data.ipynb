# %%
import pandas as pd
import numpy as np

# %%
billboard = pd.DataFrame(pd.read_csv("billboard_nodupes.csv"))
billboard
# Out:
#                   spotify_id  year                       title  \
# 0     000xQL6tZNLJzIrtIgxqSl  2017              Still Got Time
# 1     003VWU5LKbDkXTqpLQuID1  2013               The Outsiders
# 2     005lwxGU1tms6HGELIcUv9  2008             I Kissed A Girl
# 3     007n10xGvSbc7dKgAORVIq  2003           Brokenheartsville
# 4     00dhuugTq7XaBohK71vN48  2009              Sweet Caroline
# 5     00FROhC5g4iJdax5US8jRr  2000                 Satisfy You
# 6     00gvX9sFwh19OH88f4v4jW  2005     Who Did You Think I Was
# 7     00Mb3DuaIH1kjrwOku9CGU  2003                   Sk8er Boi
# 8     00mJ9I0iyXv8VJY2fWvUHQ  2001               Midwest Swing
# 9     00NAQYOP4AmWR549nnYJZu  2016                     Secrets
# 10    00NUqFMIpCsrYPbM9YpVHQ  2011                     MegaMan
# 11    00RYiT3a2lNQ1wTKBQXWSw  2008                  Lookin Boy
# 12    00YAhmYqomnoWd7ogDUtXU  2010                    I'm Back
# 13    00zqTWtvCWvDtAqoLRl6Sy  2009               When It Hurts
# ...

# %%
billboard['year'].count()
# Out:
# 7035

# %%
unpopular = pd.DataFrame(pd.read_csv("unpopular_songs_nodupes.csv"))
unpopular
# Out:
#        year                                         title  \
# 0      2000                         A Smile In Your Heart
# 1      2000             The Firm: Main Title, Ray's Blues
# 2      2000                              No/Don't Wake Up
# 3      2000                              Modern Crusaders
# 4      2000                           Listen To The Flies
# 5      2000                               Honor and Glory
# 6      2000                            Caroline I See You
# 7      2000                            Carry Me On My Way
# 8      2000                                  October Road
# 9      2000                            On the 4th of July
# 10     2000                           Always, In All Ways
# 11     2000                           Difficult By Design
# 12     2000   Everything I Do Gohn Be Funky (From Now On)
# 13     2000                               Black Velveteen
# 14     2000                                Mr. Cab Driver
# ...

# %%
sampled_unpopular = pd.DataFrame(unpopular.groupby('year').apply(lambda x: x.sample(352)))
sampled_unpopular.to_csv("sampled_unpopular.csv")
sampled_unpopular
# Out:
#             year                                              title  \
# year
# 2000 1072   2000                                      She's My Baby
#      1283   2000                        The Good Witch Of The North
#      1404   2000                                 I Wouldn't Go Back
#      1074   2000                 Couldn't You Keep That To Yourself
#      1126   2000                                I'll Be True To You
#      1393   2000                                       Tension Head
#      1342   2000                                A Place In The Dirt
#      1199   2000                                          The Grobe
#      1311   2000                                  I Won't Back Down
#      6      2000                                 Caroline I See You
#      1419   2000                        When You Say Nothing At All
#      1176   2000                                More Than a Mystery
#      1073   2000                Sweet Talking Woman (New Recording)
# ...
