# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '86cbac3f80b247908aa182f39523acb7'
client_secret = '69eb2ac93dd34387ab3df18f69e8f081'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
songs_no_id_df = pd.DataFrame(pd.read_csv("songs_no_id.csv", header=None))
songs_no_id_df
# Out:
#                                         0
# 0                              15 Minutes
# 1           Do It Again (Put Ya Hands Up)
# 2                       I Need A Hot Girl
# 3                               Take That
# 4                           Dancing Queen
# 5                                   Ta Da
# 6                                  Do You
# 7                       A Little Gasoline
# 8                           Project Chick
# 9                          Get Crunked Up
# 10                             Like, Wow!
# 11           Guilty Until Proven Innocent
# 12                           Oochie Wally
# 13                           Let's Get It
# 14                        Just A Baby Boy
# 15            If You Can Do Anything Else
# 16                      Superwoman Pt. II
# 17                     Angry All The Time
# 18           From Her Mama (Mama Got A**)
# 19                               Down 4 U
# 20                         Make Me A Song
# ...

# %%
import pandas as pd

billboard_new = pd.read_csv("2000-01-01_to_2019-10-26.csv", header=None)
unknown_ids = []
track = billboard_new[0]
artist = billboard_new[1]

for n in range(len(billboard_new[0]) - 1):
    try:
        result = sp.search(str(billboard_new[0][n+1]) + ' ' + str(billboard_new[1][n+1]))
        unknown_ids.append(result['tracks']['items'][0]['id'])
        unknown_year.append(result['tracks']['items'][0]['album']['release_date'])
    except IndexError:
        pass
# Out:
# 0                                Artist
# 1          Santana Featuring Rob Thomas
# 2                        Brian McKnight
# 3                       Jessica Simpson
# 4                       Whitney Houston
#                       ...
# 103496                      Post Malone
# 103497                      Keith Urban
# 103498                             Joji
# 103499    Young Thug Featuring Lil Baby
# 103500       YoungBoy Never Broke Again
# Name: 1, Length: 103501, dtype: object

# %%
billboard_new[0][0]
# Out:
# 'Track'

# %%
#len(year)

title_id_year_df = pd.DataFrame({"ID":ids, "Year":year})

title_id_year_df.to_csv("TitleIDYear")

# %%
lyrics_clean = pd.read_csv("TitleIDYear_2000_2018.csv")
#lyrics_clean.groupby('Year').count()
title_2000_2018_df = pd.DataFrame(lyrics_clean)
title_2000_2018_df
# Out:
#                            ID  Year
# 0      034zHn5tOZLlwDxv0zy3rj  2000
# 1      7f1Dmr246cJ9uQYdbplTbh  2000
# 2      541J7UIPHH6SD5HrfjutVa  2000
# 3      4ARqAFE8JjUg9n46eRptkr  2000
# 4      65fqcmj2M1EiERwDoIflDt  2000
# 5      7f1Dmr246cJ9uQYdbplTbh  2000
# 6      5GR1Jj5ahZtoR6WqyM5LP4  2000
# 7      26rgP1UQaxbdRfcEvu7qpk  2000
# 8      1okkbWaL4Nign0nmFvz49C  2000
# 9      5GR1Jj5ahZtoR6WqyM5LP4  2000
# 10     0etnhw0hN9uq2hkxfj58xl  2000
# 11     0n4TOY0V4lZA6lgqQ8Q6X3  2000
# 12     0WqZ6MR1Xmz3MCaWA4HZ8x  2000
# 13     0nILp5SpecXFvJQotZe48y  2000
# 14     6I8oqGgmpXTzVcB7xk2SdC  2000
# 15     3oxOwJOhn29dU1smsW9klD  2000
# 16     7JAdbrifaj8P81CjoNVjfo  2000
# 17     4VTf5dPyBntcYFwW9b3fto  2000
# 18     7ptNdKLu4PHKcma1zCAQLW  2000
# 19     1SPrdIUNZRehQbiravoPcB  2000
# 20     1eUm0m66iEq32pJnTCYhpS  2000
# 21     7f1Dmr246cJ9uQYdbplTbh  2000
# 22     7lXaXjvXdOCTqc22U46lVs  2000
# 23     1raWfcURBd1Q3W3K0ojDCM  2000
# 24     4ybK6X60TURNCfVNtInRYk  2000
# ...

# %%
title_2000_2018_df['ID'][1:3]
# Out:
# 1    7f1Dmr246cJ9uQYdbplTbh
# 2    541J7UIPHH6SD5HrfjutVa
# Name: ID, dtype: object

# %%
result = sp.track('7foypmc7KZyU716Yv63BPe')
result
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6extd4B6hl8VTmnlhpl2bY'},
#     'href': 'https://api.spotify.com/v1/artists/6extd4B6hl8VTmnlhpl2bY',
#     'id': '6extd4B6hl8VTmnlhpl2bY',
#     'name': 'Huncho Jack',
#     'type': 'artist',
#     'uri': 'spotify:artist:6extd4B6hl8VTmnlhpl2bY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#     'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#     'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#     'name': 'Travis Scott',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#     'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#     'id': '0VRj0yCOv2FXJNP47XQnx5',
#     'name': 'Quavo',
#     'type': 'artist',
#     'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'}],
# ...

# %%
result = sp.track('4F55RCGuM477OjznpYGhYz')
result['album']
# Out:
# {'album_type': 'compilation',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7352aRY2mqSxBZwzUb6LmA'},
#    'href': 'https://api.spotify.com/v1/artists/7352aRY2mqSxBZwzUb6LmA',
#    'id': '7352aRY2mqSxBZwzUb6LmA',
#    'name': 'Bow Wow',
#    'type': 'artist',
#    'uri': 'spotify:artist:7352aRY2mqSxBZwzUb6LmA'}],
#  'available_markets': ['US'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/1dQGXePMNkrSavN2pxF48a'},
#  'href': 'https://api.spotify.com/v1/albums/1dQGXePMNkrSavN2pxF48a',
#  'id': '1dQGXePMNkrSavN2pxF48a',
#  'images': [{'height': 579,
#    'url': 'https://i.scdn.co/image/be8ae636cccb38049f3df0f43c468d92dcd7c62f',
#    'width': 640},
#   {'height': 271,
#    'url': 'https://i.scdn.co/image/1ace0ec22025de9e185d2c6d785891dc014f7403',
#    'width': 300},
#   {'height': 58,
#    'url': 'https://i.scdn.co/image/f4e924c9d6f8756dbadcf3a230162a27c7fe81dc',
#    'width': 64}],
#  'name': 'Playlist: The Very Best Of Bow Wow',
# ...

# %%
audio = sp.audio_features('1uPrIHgYztXSkkcts9jet8')
audio[0]['energy']
# Out:
# 0.95

# %%
unknown_energy = []
unknown_liveness = []
unknown_tempo = []
unknown_speechiness = []
unknown_acousticness = []
unknown_instrumentalness = []
unknown_time_signature = []
unknown_danceability = []
unknown_key = []
unknown_duration_ms = []
unknown_loudness = []
unknown_valence = []
unknown_mode = []
unknown_title = []
unknown_artist = []


for ids in unknown_ids:
    audio = sp.audio_features(ids)
    
    unknown_energy.append(audio[0]['energy'])
    unknown_liveness.append(audio[0]['liveness'])
    unknown_tempo.append(audio[0]['tempo'])
    unknown_speechiness.append(audio[0]['speechiness'])
    unknown_acousticness.append(audio[0]['acousticness'])
    unknown_instrumentalness.append(audio[0]['instrumentalness'])
    unknown_time_signature.append(audio[0]['time_signature'])
    unknown_danceability.append(audio[0]['danceability'])
    unknown_key.append(audio[0]['key'])
    unknown_duration_ms.append(audio[0]['duration_ms'])
    unknown_loudness.append(audio[0]['loudness'])
    unknown_valence.append(audio[0]['valence'])
    unknown_mode.append(audio[0]['mode'])
    
    name = sp.track(ids)
    unknown_title.append(name['album']['artists'][0]['name'])
    unknown_artist.append(name['name'])

# %%
unknown_af = pd.DataFrame({'year':unknown_year,
                          'title':unknown_artist,
                          'artist':unknown_title,
                          'id': unknown_ids,
                          'energy':unknown_energy, 
                          'liveness': unknown_liveness, 
                          'tempo': unknown_tempo, 
                          'speechiness': unknown_speechiness, 
                          'acousticness': unknown_acousticness, 
                          'instrumentalness': unknown_instrumentalness, 
                          'time_signature': unknown_time_signature, 
                          'danceability': unknown_danceability, 
                          'key': unknown_key, 
                          'duration_ms': unknown_duration_ms, 
                          'loudness': unknown_loudness, 
                          'valence': unknown_valence, 
                          'mode': unknown_mode})
unknown_af.to_csv("unknown_audio_features.csv")
unknown_af
# Out:
#            year                                              title  \
# 0    2019-09-06                                         15 MINUTES
# 1    2010-11-24  Do It Again Put Ya Hands Up - Instrumental Hip...
# 2    1999-07-27                                  I Need A Hot Girl
# 3    1997-05-20                  They Can't Take That Away From Me
# 4          1976                                      Dancing Queen
# 5    2018-11-19                          De Nho Mot Thoi Ta Da Yeu
# 6    2019-07-19                                  How Do You Sleep?
# 7    2000-09-19                                  A Little Gasoline
# 8    2019-05-17                                      Project Chick
# 9    2003-01-01                                     get crunked up
# 10   2006-12-15                                  Shortie Like Mine
# 11   2017-07-14                                     Can't Touch Me
# 12   2000-11-06                               Oochie Wally - Remix
# ...

# %%
sample = lambda obj: obj.loc[np.random.choice(obj.index, , replace),:]
title_2000_2018_df.groupby('Year', as_index=False).apply(fn)

# %%
result = sp.search(new_data[0][22])
result
type(result['tracks']['items'][0])
# Out:
# dict

# %%
result['tracks']['items'][0]['album']['release_date']
# Out:
# '1981'

# %%
for key, value in result['tracks']['items'][0].items():
    print (key)
# Out:
# album
# artists
# available_markets
# disc_number
# duration_ms
# explicit
# external_ids
# external_urls
# href
# id
# is_local
# name
# popularity
# preview_url
# track_number
# type
# uri

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
ids = []


for title in new_data:
    try:
        result = sp.search(title)
        ids.append(result['tracks']['items'][0]['id'])

        ''' if request_count % 5 == 0:
            print(str(request_count) + " playlists completed")
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            print('Loop #: {}'.format(request_count))
            print('Elapsed Time: {} seconds'.format(time.time() - start_time))'''
    except IndexError:
        result = sp.search(title)
        ids.append(result['tracks']['items'][0]['id'])
    
ids
# Out:
# ['4XfCa8VFYeTsKbXrVlpKIa']

# %%
len(ids)
# Out:
# 17

# %%
name = "We Will Rock You"

result = sp.search(name)
result['tracks']['items'][0]['id']

# %%
#Extracting artist's uri
artist_uri = result['tracks']['items'][0]['artists'][0]['uri']

#Pulling all of the artist's albums
sp_albums = sp.artist_albums(artist_uri, album_type='album')

#Storing albums and uris in lists
album_names = []
album_uris = []

for i in range(len(sp_albums['items'])):
    album_names.append(sp_albums['items'][i]['name'])
    album_uris.append(sp_albums['items'][i]['uri'])
    
album_names
#album_uris
# Out:
# ['Bohemian Rhapsody (The Original Soundtrack)',
#  'Bohemian Rhapsody (The Original Soundtrack)',
#  'On Air',
#  'Queen On Air',
#  'A Night At The Odeon',
#  'A Night at the Odeon',
#  'Live At The Rainbow',
#  'Live At The Rainbow (Deluxe)',
#  'Live at the Rainbow ‘74',
#  'Hungarian Rhapsody (Live In Budapest / 1986)',
#  'The Platinum Collection (Greatest Hits I II & III - 2011 Remaster)',
#  'The Cosmos Rocks',
#  'Queen Rock Montreal',
#  'Queen Rock Montreal',
#  'Return Of The Champions',
#  'On Fire: Live At The Bowl',
#  'On Fire: Live At The Bowl',
#  'Made In Heaven',
#  'Made In Heaven (2011 Remaster)',
#  'Made In Heaven']

# %%
def albumSongs(uri):
    
    album = uri #assign album uri to a_name
    spotify_albums[album] = {} #creates dictionary for specific album
    
    #create key-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    
    tracks = sp.album_tracks(album) #pull data on album tracks
    
    for n in range(len(tracks['items'])): #for each song track
        spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album count
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0

for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #updating the album count once all tracks have been added
# Out:
# Album Bohemian Rhapsody (The Original Soundtrack) songs has been added to spotify_albums dictionary
# Album Bohemian Rhapsody (The Original Soundtrack) songs has been added to spotify_albums dictionary
# Album On Air songs has been added to spotify_albums dictionary
# Album Queen On Air songs has been added to spotify_albums dictionary
# Album A Night At The Odeon songs has been added to spotify_albums dictionary
# Album A Night at the Odeon songs has been added to spotify_albums dictionary
# Album Live At The Rainbow songs has been added to spotify_albums dictionary
# Album Live At The Rainbow (Deluxe) songs has been added to spotify_albums dictionary
# Album Live at the Rainbow ‘74 songs has been added to spotify_albums dictionary
# Album Hungarian Rhapsody (Live In Budapest / 1986) songs has been added to spotify_albums dictionary
# Album The Platinum Collection (Greatest Hits I II & III - 2011 Remaster) songs has been added to spotify_albums dictionary
# ...

# %%
def audio_features(album):
    
    #add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    
    #create a track counter
    track_count = 0
    
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
# loop through albums extracting the audio features
# to avoid sending too many requests at Spotify's API we add a random delay every few albums
# also setting up print statements to track which album we are on in case of errors and where it happened

import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0

for i in new_data:
    audio_features(i)
    request_count+=1
    
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b7656767dcd5> in <module>
#      11
#      12 for i in new_data:
# ---> 13     audio_features(i)
#      14     request_count+=1
#      15
#
# <ipython-input-10-b39e6bc516f2> in audio_features(album)
#       2
#       3     #add new key-values to store audio features
# ----> 4     spotify_albums[album]['acousticness'] = []
#       5     spotify_albums[album]['danceability'] = []
#       6     spotify_albums[album]['energy'] = []
#
# NameError: name 'spotify_albums' is not defined

# %%
# loop through albums extracting the audio features
# to avoid sending too many requests at Spotify's API we add a random delay every few albums
# also setting up print statements to track which album we are on in case of errors and where it happened

import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0

for i in spotify_albums:
    audio_features(i)
    request_count+=1
    
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 36.02680802345276 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 84.5358145236969 seconds
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 130.92723941802979 seconds
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 161.01207947731018 seconds

# %%
# adding data to a new data frame
# first organizing data into a dictionary to be converted into a DF
dic_df = {}

dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []

for album in spotify_albums:
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 498

# %%
# converting into a DF
import pandas as pd

df = pd.DataFrame.from_dict(dic_df)
df
# Out:
#                                            album  track_number  \
# 0    Bohemian Rhapsody (The Original Soundtrack)             1
# 1    Bohemian Rhapsody (The Original Soundtrack)             2
# 2    Bohemian Rhapsody (The Original Soundtrack)             3
# 3    Bohemian Rhapsody (The Original Soundtrack)             4
# 4    Bohemian Rhapsody (The Original Soundtrack)             5
# 5    Bohemian Rhapsody (The Original Soundtrack)             6
# 6    Bohemian Rhapsody (The Original Soundtrack)             7
# 7    Bohemian Rhapsody (The Original Soundtrack)             8
# 8    Bohemian Rhapsody (The Original Soundtrack)             9
# 9    Bohemian Rhapsody (The Original Soundtrack)            10
# 10   Bohemian Rhapsody (The Original Soundtrack)            11
# 11   Bohemian Rhapsody (The Original Soundtrack)            12
# 12   Bohemian Rhapsody (The Original Soundtrack)            13
# 13   Bohemian Rhapsody (The Original Soundtrack)            14
# ...

# %%
# remove duplicates
# apparently spotify has a duplicate issue so we fix this by removing all but the most popular songs

print(len(df))
final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 498
# 334

# %%
final_df.to_csv("QueenAlbumsAudioFeatures")
