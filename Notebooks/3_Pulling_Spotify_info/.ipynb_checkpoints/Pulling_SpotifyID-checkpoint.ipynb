# %%
import spotipy, pandas as pd
from datascience import *

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '86cbac3f80b247908aa182f39523acb7'
client_secret = '69eb2ac93dd34387ab3df18f69e8f081'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
songs_no_id = pd.read_csv("combined_unique.csv")
songs_no_id_df = pd.DataFrame(songs_no_id)
songs_no_id_df
# Out:
#                           Track                        Artist  Position  Peak  \
# 0                        Smooth  Santana Featuring Rob Thomas       1.0   1.0
# 1                   Back At One                Brian McKnight       2.0   2.0
# 2      I Wanna Love You Forever               Jessica Simpson       3.0   3.0
# 3          My Love Is Your Love               Whitney Houston       4.0   4.0
# 4            I Knew I Loved You                 Savage Garden       5.0   4.0
# ...                         ...                           ...       ...   ...
# 64644             Good Old Days                  Ziggy Marley       0.0   0.0
# 64645             Hand To Mouth                  Ziggy Marley       0.0   0.0
# 64646              Come With Me                          Zwan       0.0   0.0
# 64647                    Desire                          Zwan       0.0   0.0
# 64648                 Heartsong                          Zwan       0.0   0.0
#
# ...

# %%
current_track = []
current_artist = []
unknown_ids = []
unknown_years = []
track = songs_no_id_df['Track']
artist = songs_no_id_df['Artist']

for n in range(len(track)):
    
    try:
        result = sp.search(str(songs_no_id['Track'][n]) + ' ' + str(songs_no_id['Artist'][n]))
        unknown_ids.append(result['tracks']['items'][0]['id'])
        unknown_years.append(result['tracks']['items'][0]['album']['release_date'])
        current_track.append(songs_no_id['Track'][n])
        current_artist.append(songs_no_id['Artist'][n])
    
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/src/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-90af1ae11b46> in <module>
#       8 for n in range(len(track)):
#       9     try:
# ---> 10         result = sp.search(str(songs_no_id['Track'][n]) + ' ' + str(songs_no_id['Artist'][n]))
# ...

# %%
songs_with_id = Table.from_df(songs_no_id_df)
songs_with_id_table = songs_with_id.with_columns('ID', unknown_ids, 'Release', unknown_years)
songs_with_id_table
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e08588a8835c> in <module>
#       1 songs_with_id = Table.from_df(songs_no_id_df)
# ----> 2 songs_with_id_table = songs_with_id.with_columns('ID', unknown_ids, 'Release', unknown_years)
#       3 songs_with_id_table
#
# /usr/local/src/anaconda3/lib/python3.7/site-packages/datascience/tables.py in with_columns(self, *labels_and_values)
#    1681         for i in range(0, len(labels_and_values), 2):
#    1682             label, values = labels_and_values[i], labels_and_values[i+1]
# -> 1683             self = self.with_column(label, values)
#    1684         return self
#    1685
#
# /usr/local/src/anaconda3/lib/python3.7/site-packages/datascience/tables.py in with_column(self, label, values, *rest)
#    1604
#    1605         new_table = self.copy()
# -> 1606         new_table.append_column(label, values)
# ...
